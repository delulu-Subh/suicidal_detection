# %% [markdown]
# # 03 Feature Engineering
# Reusable project modules are the source of truth.

# %%
from src.features.tfidf_features import TFIDFFeatureExtractor
TFIDFFeatureExtractor(include_char=False).fit_transform(["example text", "another example"])
