# %% [markdown]
# # 05 Evaluation
# Reusable project modules are the source of truth.

# %%
import json
from src.config import METRICS_DIR
json.loads((METRICS_DIR / "model_comparison.json").read_text())
