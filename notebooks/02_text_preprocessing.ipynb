# %% [markdown]
# # 02 Text Preprocessing
# Reusable project modules are the source of truth.

# %%
from src.preprocessing.cleaner import TextCleaner
TextCleaner().clean("Example post!!! https://example.org")
